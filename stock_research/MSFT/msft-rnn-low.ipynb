# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='MSFT'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 5s 22ms/step - loss: 0.0560 - val_loss: 0.0470
# Epoch 2/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0239 - val_loss: 0.0041
# Epoch 3/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0167 - val_loss: 0.0074
# Epoch 4/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0160 - val_loss: 0.0295
# Epoch 5/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0157 - val_loss: 0.0431
# Epoch 6/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0148 - val_loss: 0.0081
# Epoch 7/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0140 - val_loss: 7.0420e-04
# Epoch 8/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0125 - val_loss: 0.0039
# Epoch 9/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0109 - val_loss: 0.0202
# Epoch 10/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0101 - val_loss: 0.0028
# Epoch 11/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0111 - val_loss: 0.0021
# Epoch 12/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0081 - val_loss: 0.0027
# Epoch 13/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0093 - val_loss: 0.0012
# Epoch 14/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 15/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 0.0134
# Epoch 16/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0019
# Epoch 17/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0110
# Epoch 18/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0082 - val_loss: 2.2026e-04
# Epoch 19/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0083 - val_loss: 0.0131
# Epoch 20/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 21/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0227
# Epoch 22/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0069 - val_loss: 0.0195
# Epoch 23/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 24/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0080 - val_loss: 0.0103
# Epoch 25/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 26/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 8.5331e-04
# Epoch 27/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0073 - val_loss: 7.7843e-04
# Epoch 28/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 29/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0050
# Epoch 30/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0080 - val_loss: 6.3452e-04
# Epoch 31/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0058 - val_loss: 0.0096
# Epoch 32/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 33/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 34/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 35/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0075 - val_loss: 0.0050
# Epoch 36/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0058 - val_loss: 2.5345e-04
# Epoch 37/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 38/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0079 - val_loss: 0.0138
# Epoch 39/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0064 - val_loss: 0.0028
# Epoch 40/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 41/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0057 - val_loss: 0.0023
# Epoch 42/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 43/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0062 - val_loss: 0.0099
# Epoch 44/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 45/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 46/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0058 - val_loss: 0.0150
# Epoch 47/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0070 - val_loss: 2.1319e-04
# Epoch 48/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0066 - val_loss: 0.0188
# Epoch 49/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0065 - val_loss: 1.0721e-04
# Epoch 50/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0052 - val_loss: 4.7331e-08

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(5, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='adam', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0759
# Epoch 2/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0329
# Epoch 3/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0295
# Epoch 4/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0192
# Epoch 5/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0213
# Epoch 6/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0153
# Epoch 7/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0161
# Epoch 8/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0153
# Epoch 9/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0140
# Epoch 10/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0132
# Epoch 11/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0142
# Epoch 12/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0140
# Epoch 13/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0125
# Epoch 14/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0136
# Epoch 15/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0128
# Epoch 16/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0131
# Epoch 17/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0107
# Epoch 18/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0127
# Epoch 19/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0125
# Epoch 20/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0098
# Epoch 21/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0116
# Epoch 22/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0110
# Epoch 23/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0124
# Epoch 24/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0114
# Epoch 25/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0121
# Epoch 26/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0117
# Epoch 27/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0111
# Epoch 28/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0104
# Epoch 29/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0123
# Epoch 30/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0106
# Epoch 31/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0105
# Epoch 32/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0117
# Epoch 33/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0119
# Epoch 34/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0115
# Epoch 35/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0095
# Epoch 36/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0108
# Epoch 37/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0088
# Epoch 38/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0092
# Epoch 39/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0105
# Epoch 40/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0121
# Epoch 41/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0116
# Epoch 42/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0114
# Epoch 43/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0158
# Epoch 44/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0119
# Epoch 45/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0121
# Epoch 46/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0122
# Epoch 47/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0090
# Epoch 48/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0085
# Epoch 49/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0517
# Epoch 50/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0116

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[174.09133721],
#        [174.14697079],
#        [174.16884062],
#        [174.16712369],
#        [174.1496246 ],
#        [174.12220187],
#        [174.08949563],
#        [174.05424012],
#        [174.01871923],
#        [173.98499972],
#        [173.95468191],
#        [173.92743609],
#        [173.90420316],
#        [173.88475795],
#        [173.86877878],
#        [173.85663557],
#        [173.8468808 ],
#        [173.83973963],
#        [173.83496276]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
