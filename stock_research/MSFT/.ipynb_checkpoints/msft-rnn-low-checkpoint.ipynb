# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='MSFT'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 213 steps, validate for 1 steps
# Epoch 1/50
# 213/213 [==============================] - 3s 15ms/step - loss: 0.0466 - val_loss: 0.0228
# Epoch 2/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0283 - val_loss: 0.0311
# Epoch 3/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0158 - val_loss: 0.0102
# Epoch 4/50
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0149 - val_loss: 5.7797e-04
# Epoch 5/50
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0115 - val_loss: 0.0020
# Epoch 6/50
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 0.0122
# Epoch 7/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0101 - val_loss: 0.0172
# Epoch 8/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0011
# Epoch 9/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0133 - val_loss: 0.0206
# Epoch 10/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0077 - val_loss: 0.0010
# Epoch 11/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 1.3636e-04
# Epoch 12/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0088 - val_loss: 0.0045
# Epoch 13/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0082 - val_loss: 1.2595e-04
# Epoch 14/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0085 - val_loss: 0.0029
# Epoch 15/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0104 - val_loss: 6.1754e-05
# Epoch 16/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0086 - val_loss: 0.0055
# Epoch 17/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0108 - val_loss: 1.0343e-04
# Epoch 18/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 4.7137e-06
# Epoch 19/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0079
# Epoch 20/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 21/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0040
# Epoch 22/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0080 - val_loss: 0.0036
# Epoch 23/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0073 - val_loss: 0.0017
# Epoch 24/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 25/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0062
# Epoch 26/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 27/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0067 - val_loss: 0.0126
# Epoch 28/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 29/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0072 - val_loss: 0.0111
# Epoch 30/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 6.9932e-04
# Epoch 31/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 32/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0072 - val_loss: 5.3056e-04
# Epoch 33/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0074 - val_loss: 0.0186
# Epoch 34/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 35/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0026
# Epoch 36/50
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 37/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 38/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0062 - val_loss: 0.0147
# Epoch 39/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 1.2971e-04
# Epoch 40/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0093 - val_loss: 5.4354e-07
# Epoch 41/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0073 - val_loss: 1.9542e-04
# Epoch 42/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 0.0023
# Epoch 43/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0057 - val_loss: 6.0334e-06
# Epoch 44/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0076 - val_loss: 0.0162
# Epoch 45/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0069 - val_loss: 0.0034
# Epoch 46/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0074 - val_loss: 2.7292e-04
# Epoch 47/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 48/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 49/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0070 - val_loss: 0.0081
# Epoch 50/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0063 - val_loss: 4.6467e-04

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='adam', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 233 steps
# Epoch 1/50
# 233/233 [==============================] - 4s 17ms/step - loss: 0.0264
# Epoch 2/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0145
# Epoch 3/50
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0163
# Epoch 4/50
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0129
# Epoch 5/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0134
# Epoch 6/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0098
# Epoch 7/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0108
# Epoch 8/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0080
# Epoch 9/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0086
# Epoch 10/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0120
# Epoch 11/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0087
# Epoch 12/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0119
# Epoch 13/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0100
# Epoch 14/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0077
# Epoch 15/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0098
# Epoch 16/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0087
# Epoch 17/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0090
# Epoch 18/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0094
# Epoch 19/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0082
# Epoch 20/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0104
# Epoch 21/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0079
# Epoch 22/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0078
# Epoch 23/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0105
# Epoch 24/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0078
# Epoch 25/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0075
# Epoch 26/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0113
# Epoch 27/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0071
# Epoch 28/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0094
# Epoch 29/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0073
# Epoch 30/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0080
# Epoch 31/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0075
# Epoch 32/50
# 233/233 [==============================] - 3s 11ms/step - loss: 0.0079
# Epoch 33/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0080
# Epoch 34/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0087
# Epoch 35/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0103
# Epoch 36/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0081
# Epoch 37/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0079
# Epoch 38/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0076
# Epoch 39/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0083
# Epoch 40/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0079
# Epoch 41/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0060
# Epoch 42/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0077
# Epoch 43/50
# 233/233 [==============================] - 2s 10ms/step - loss: 0.0072
# Epoch 44/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0080
# Epoch 45/50
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0071
# Epoch 46/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0078
# Epoch 47/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0070
# Epoch 48/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0069
# Epoch 49/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0064
# Epoch 50/50
# 233/233 [==============================] - 2s 9ms/step - loss: 0.0065

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[172.50948755],
#        [171.44206754],
#        [170.23932717],
#        [168.98222384],
#        [167.73107148],
#        [166.51482884],
#        [165.3835243 ],
#        [164.35431116],
#        [163.42225573],
#        [162.58000373],
#        [161.82019285],
#        [161.13488577],
#        [160.51783798],
#        [159.93920616],
#        [159.36513406],
#        [158.81892299],
#        [158.29660829],
#        [157.79487272],
#        [157.31152485]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
# Out:
#               Forecast
# 2020-05-02  172.509488
# 2020-05-03  171.442068
# 2020-05-04  170.239327
# 2020-05-05  168.982224
# 2020-05-06  167.731071
# 2020-05-07  166.514829
# 2020-05-08  165.383524
# 2020-05-09  164.354311
# 2020-05-10  163.422256
# 2020-05-11  162.580004
# 2020-05-12  161.820193
# 2020-05-13  161.134886
# 2020-05-14  160.517838
# 2020-05-15  159.939206
# 2020-05-16  159.365134
# 2020-05-17  158.818923
# 2020-05-18  158.296608
# 2020-05-19  157.794873
# 2020-05-20  157.311525
