# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='GOOG'
stock_parameter ='Low'
epoch_number=200

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=200,
                   validation_data=validation_generator)
# Out:
# loss: 0.0138 - val_loss: 0.0028
# Epoch 12/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0129 - val_loss: 0.0037
# Epoch 13/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0123 - val_loss: 0.0016
# Epoch 14/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0166 - val_loss: 0.0051
# Epoch 15/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0139 - val_loss: 1.5717e-04
# Epoch 16/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0145 - val_loss: 4.0839e-04
# Epoch 17/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0125 - val_loss: 9.6285e-04
# Epoch 18/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0131 - val_loss: 0.0022
# Epoch 19/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0110 - val_loss: 7.5173e-04
# Epoch 20/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0097 - val_loss: 0.0040
# Epoch 21/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0153 - val_loss: 2.1697e-04
# Epoch 22/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0124 - val_loss: 0.0024
# Epoch 23/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0124 - val_loss: 9.6031e-05
# Epoch 24/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0120 - val_loss: 3.7656e-04
# Epoch 25/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0106 - val_loss: 0.0147
# Epoch 26/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0137 - val_loss: 3.8577e-05
# Epoch 27/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0128 - val_loss: 4.7206e-05
# Epoch 28/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0113 - val_loss: 0.0011
# Epoch 29/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 6.4165e-04
# Epoch 30/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0123 - val_loss: 0.0058
# Epoch 31/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0095 - val_loss: 0.0033
# Epoch 32/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0119 - val_loss: 0.0040
# Epoch 33/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0103 - val_loss: 2.9708e-05
# Epoch 34/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0098 - val_loss: 5.2022e-04
# Epoch 35/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0099 - val_loss: 9.6733e-04
# Epoch 36/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0094 - val_loss: 6.6899e-04
# Epoch 37/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0094 - val_loss: 3.9237e-05
# Epoch 38/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0104 - val_loss: 9.8306e-06
# Epoch 39/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0099 - val_loss: 5.4562e-04
# Epoch 40/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0099 - val_loss: 0.0026
# Epoch 41/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0097 - val_loss: 6.0767e-04
# Epoch 42/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0109 - val_loss: 1.6175e-04
# Epoch 43/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0113 - val_loss: 0.0013
# Epoch 44/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0103 - val_loss: 4.9600e-05
# Epoch 45/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 2.4862e-04
# Epoch 46/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0087 - val_loss: 3.0135e-04
# Epoch 47/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0095 - val_loss: 4.4212e-04
# Epoch 48/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0093 - val_loss: 1.3647e-06
# Epoch 49/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0089 - val_loss: 5.3964e-05
# Epoch 50/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0107 - val_loss: 9.5282e-04
# Epoch 51/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0073 - val_loss: 0.0017
# Epoch 52/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0082 - val_loss: 6.8932e-04
# Epoch 53/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0109 - val_loss: 2.5052e-05
# Epoch 54/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0085 - val_loss: 9.3332e-04
# Epoch 55/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0093 - val_loss: 7.5986e-04
# Epoch 56/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 0.0010
# Epoch 57/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0098 - val_loss: 0.0033
# Epoch 58/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0114 - val_loss: 1.3200e-04
# Epoch 59/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0091 - val_loss: 2.7500e-04
# Epoch 60/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0093 - val_loss: 1.5371e-04
# Epoch 61/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0106 - val_loss: 2.2617e-05
# Epoch 62/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0102 - val_loss: 3.9155e-04
# Epoch 63/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0079 - val_loss: 4.9717e-05
# Epoch 64/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0108 - val_loss: 9.7384e-05
# Epoch 65/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0095 - val_loss: 3.5569e-04
# Epoch 66/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0115 - val_loss: 0.0013
# Epoch 67/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0102 - val_loss: 1.5104e-06
# Epoch 68/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0012
# Epoch 69/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0080 - val_loss: 1.0846e-04
# Epoch 70/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0101 - val_loss: 1.0600e-04
# Epoch 71/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0102 - val_loss: 6.4433e-05
# Epoch 72/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0078 - val_loss: 4.5829e-06
# Epoch 73/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0093 - val_loss: 0.0011
# Epoch 74/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0121 - val_loss: 3.9555e-04
# Epoch 75/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 3.0907e-04
# Epoch 76/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0088 - val_loss: 0.0017
# Epoch 77/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0093 - val_loss: 0.0030
# Epoch 78/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0081 - val_loss: 2.8853e-04
# Epoch 79/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0111 - val_loss: 1.0783e-04
# Epoch 80/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 8.1265e-05
# Epoch 81/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0095 - val_loss: 8.7061e-06
# Epoch 82/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0091 - val_loss: 0.0012
# Epoch 83/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0125 - val_loss: 5.3628e-04
# Epoch 84/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0087 - val_loss: 1.8961e-04
# Epoch 85/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0073 - val_loss: 5.7559e-06
# Epoch 86/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0082 - val_loss: 2.8870e-04
# Epoch 87/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0088 - val_loss: 8.3341e-04
# Epoch 88/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0077 - val_loss: 3.1161e-04
# Epoch 89/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0090 - val_loss: 2.3525e-04
# Epoch 90/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0089 - val_loss: 5.7712e-04
# Epoch 91/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0094 - val_loss: 2.9920e-06
# Epoch 92/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0081 - val_loss: 0.0011
# Epoch 93/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0095 - val_loss: 0.0023
# Epoch 94/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0087 - val_loss: 0.0019
# Epoch 95/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0086 - val_loss: 0.0010
# Epoch 96/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0109 - val_loss: 7.1930e-07
# Epoch 97/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0096 - val_loss: 9.0821e-05
# Epoch 98/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0098 - val_loss: 7.3624e-05
# Epoch 99/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0088 - val_loss: 0.0013
# Epoch 100/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0078 - val_loss: 1.8877e-04
# Epoch 101/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 3.6927e-04
# Epoch 102/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0097 - val_loss: 1.7792e-05
# Epoch 103/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0080 - val_loss: 2.4294e-05
# Epoch 104/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0103 - val_loss: 2.6940e-04
# Epoch 105/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0084 - val_loss: 3.5148e-04
# Epoch 106/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0086 - val_loss: 0.0015
# Epoch 107/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 0.0023
# Epoch 108/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0096 - val_loss: 3.9902e-04
# Epoch 109/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0096 - val_loss: 2.8666e-04
# Epoch 110/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 7.7587e-06
# Epoch 111/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 3.4206e-04
# Epoch 112/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0073 - val_loss: 2.6397e-04
# Epoch 113/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 114/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0090 - val_loss: 4.6699e-04
# Epoch 115/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0103 - val_loss: 3.8067e-04
# Epoch 116/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0094 - val_loss: 2.2565e-04
# Epoch 117/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0105 - val_loss: 0.0013
# Epoch 118/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0077 - val_loss: 6.9340e-05
# Epoch 119/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0082 - val_loss: 4.0158e-04
# Epoch 120/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 6.2594e-04
# Epoch 121/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0089 - val_loss: 0.0015
# Epoch 122/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0075 - val_loss: 1.8511e-06
# Epoch 123/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0096 - val_loss: 2.4106e-05
# Epoch 124/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0072 - val_loss: 3.9162e-04
# Epoch 125/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0089 - val_loss: 8.5245e-05
# Epoch 126/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0085 - val_loss: 6.3747e-05
# Epoch 127/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0088 - val_loss: 0.0011
# Epoch 128/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0091 - val_loss: 0.0026
# Epoch 129/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 130/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0100 - val_loss: 3.0497e-05
# Epoch 131/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0094 - val_loss: 0.0011
# Epoch 132/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 1.9874e-04
# Epoch 133/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0099 - val_loss: 2.5512e-04
# Epoch 134/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 3.4188e-06
# Epoch 135/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0078 - val_loss: 9.6281e-04
# Epoch 136/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 1.7587e-06
# Epoch 137/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 3.4817e-05
# Epoch 138/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 2.3152e-04
# Epoch 139/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0091 - val_loss: 4.9587e-04
# Epoch 140/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 9.1914e-04
# Epoch 141/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0092 - val_loss: 3.0514e-04
# Epoch 142/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 4.2529e-04
# Epoch 143/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 8.7417e-04
# Epoch 144/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 3.7954e-04
# Epoch 145/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 0.0024
# Epoch 146/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0079 - val_loss: 1.0322e-04
# Epoch 147/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0083 - val_loss: 0.0017
# Epoch 148/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 2.4175e-04
# Epoch 149/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 4.9449e-04
# Epoch 150/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0102 - val_loss: 5.1600e-04
# Epoch 151/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0088 - val_loss: 0.0012
# Epoch 152/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0070 - val_loss: 2.5689e-06
# Epoch 153/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 2.0839e-06
# Epoch 154/200
# 213/213 [==============================] - 3s 13ms/step - loss: 0.0073 - val_loss: 1.1898e-04
# Epoch 155/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0084 - val_loss: 2.9166e-04
# Epoch 156/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 2.7281e-04
# Epoch 157/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0081 - val_loss: 1.1906e-07
# Epoch 158/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0072 - val_loss: 0.0052
# Epoch 159/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 4.1549e-04
# Epoch 160/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 6.4196e-04
# Epoch 161/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 6.1402e-05
# Epoch 162/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 5.4917e-04
# Epoch 163/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 4.2676e-04
# Epoch 164/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0088 - val_loss: 6.1876e-04
# Epoch 165/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 3.4503e-05
# Epoch 166/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0085 - val_loss: 1.9105e-04
# Epoch 167/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 4.4755e-06
# Epoch 168/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0096 - val_loss: 4.9830e-04
# Epoch 169/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 2.4193e-04
# Epoch 170/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0098 - val_loss: 1.7924e-04
# Epoch 171/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0081 - val_loss: 6.0772e-05
# Epoch 172/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 5.4088e-05
# Epoch 173/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0077 - val_loss: 9.6079e-04
# Epoch 174/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0090 - val_loss: 5.5343e-04
# Epoch 175/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0088 - val_loss: 0.0015
# Epoch 176/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0082 - val_loss: 2.4005e-04
# Epoch 177/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0088 - val_loss: 6.1809e-09
# Epoch 178/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0090 - val_loss: 4.3460e-04
# Epoch 179/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0094 - val_loss: 7.6895e-06
# Epoch 180/200
# 213/213 [==============================] - 1s 7ms/step - loss: 0.0085 - val_loss: 1.8575e-04
# Epoch 181/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0082 - val_loss: 6.8383e-04
# Epoch 182/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 6.8086e-04
# Epoch 183/200
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0076 - val_loss: 3.6901e-04
# Epoch 184/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 2.1595e-05
# Epoch 185/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 2.1679e-04
# Epoch 186/200
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0091 - val_loss: 4.7271e-07
# Epoch 187/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0074 - val_loss: 2.5083e-06
# Epoch 188/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0094 - val_loss: 7.9765e-04
# Epoch 189/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0070 - val_loss: 1.2149e-05
# Epoch 190/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0091 - val_loss: 0.0017
# Epoch 191/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 1.5553e-05
# Epoch 192/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 2.7017e-04
# Epoch 193/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0085 - val_loss: 2.7293e-06
# Epoch 194/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0063 - val_loss: 1.4523e-05
# Epoch 195/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 1.9072e-04
# Epoch 196/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 6.1306e-04
# Epoch 197/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 7.0058e-04
# Epoch 198/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0075 - val_loss: 7.8228e-04
# Epoch 199/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0075 - val_loss: 1.7089e-04
# Epoch 200/200
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 4.4211e-04

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6dd51d7df904> in <module>
#       1 from keras.models import load_model
# ----> 2 model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock)

# %%
length=12
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
model= Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.fit_generator(generator, epochs=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4ffaa8d0b8d0> in <module>
# ----> 1 model= Sequential()
#       2 model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
#       3 model.add(Dropout(0.2))
#       4 model.add(Dense(50, activation='relu'))
#       5 model.add(Dropout(0.2))
#
# NameError: name 'Sequential' is not defined

# %%
forecast =[]

periods=12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
