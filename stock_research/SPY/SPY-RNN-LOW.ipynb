# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='SPY'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 8s 39ms/step - loss: 0.1041 - val_loss: 0.0103
# Epoch 2/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0410 - val_loss: 2.9449e-04
# Epoch 3/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0298 - val_loss: 0.0041
# Epoch 4/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0262 - val_loss: 0.0225
# Epoch 5/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0245 - val_loss: 0.0064
# Epoch 6/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0194 - val_loss: 1.0627e-05
# Epoch 7/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0212 - val_loss: 6.9531e-04
# Epoch 8/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0158 - val_loss: 4.1651e-04
# Epoch 9/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0160 - val_loss: 0.0029
# Epoch 10/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0113 - val_loss: 0.0138
# Epoch 11/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0138 - val_loss: 5.4427e-04
# Epoch 12/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0121 - val_loss: 0.0095
# Epoch 13/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0106 - val_loss: 0.0061
# Epoch 14/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0093 - val_loss: 0.0018
# Epoch 15/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0106 - val_loss: 0.0054
# Epoch 16/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 17/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0097 - val_loss: 0.0137
# Epoch 18/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0083 - val_loss: 0.0047
# Epoch 19/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0077 - val_loss: 3.9427e-04
# Epoch 20/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0079 - val_loss: 0.0017
# Epoch 21/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0061 - val_loss: 0.0078
# Epoch 22/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0070 - val_loss: 0.0024
# Epoch 23/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0058 - val_loss: 3.8534e-04
# Epoch 24/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0081 - val_loss: 0.0047
# Epoch 25/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0064 - val_loss: 0.0030
# Epoch 26/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 27/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0061 - val_loss: 0.0078
# Epoch 28/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0077 - val_loss: 0.0038
# Epoch 29/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 30/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 31/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0059 - val_loss: 0.0089
# Epoch 32/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 33/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0026
# Epoch 34/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 35/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 36/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 37/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0055 - val_loss: 0.0138
# Epoch 38/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 39/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0067 - val_loss: 0.0039
# Epoch 40/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 41/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 42/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 43/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0046 - val_loss: 0.0090
# Epoch 44/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0052 - val_loss: 0.0079
# Epoch 45/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0055 - val_loss: 0.0075
# Epoch 46/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0083
# Epoch 47/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0054 - val_loss: 0.0090
# Epoch 48/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0055 - val_loss: 0.0079
# Epoch 49/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0053 - val_loss: 0.0071
# Epoch 50/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0049 - val_loss: 0.0095

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='adam', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 5s 21ms/step - loss: 0.1019
# Epoch 2/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0349
# Epoch 3/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0227
# Epoch 4/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0224
# Epoch 5/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0175
# Epoch 6/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0177
# Epoch 7/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0155
# Epoch 8/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0158
# Epoch 9/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0153
# Epoch 10/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0131
# Epoch 11/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0116
# Epoch 12/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0125
# Epoch 13/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0118
# Epoch 14/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0091
# Epoch 15/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0100
# Epoch 16/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0097
# Epoch 17/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0080
# Epoch 18/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0088
# Epoch 19/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0092
# Epoch 20/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0087
# Epoch 21/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0075
# Epoch 22/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0074
# Epoch 23/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0063
# Epoch 24/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0062
# Epoch 25/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0068
# Epoch 26/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0055
# Epoch 27/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 28/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0059
# Epoch 29/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0053
# Epoch 30/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0063
# Epoch 31/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0052
# Epoch 32/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0052
# Epoch 33/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0071
# Epoch 34/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0057
# Epoch 35/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0051
# Epoch 36/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0058
# Epoch 37/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0058
# Epoch 38/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0048
# Epoch 39/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0054
# Epoch 40/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0048
# Epoch 41/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0047
# Epoch 42/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0039
# Epoch 43/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0060
# Epoch 44/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0049
# Epoch 45/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0054
# Epoch 46/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0044
# Epoch 47/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0044
# Epoch 48/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0045
# Epoch 49/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0037
# Epoch 50/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0052

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[291.16125392],
#        [292.79569901],
#        [293.95707192],
#        [294.73191033],
#        [295.36375336],
#        [295.93230976],
#        [296.43306717],
#        [296.89042784],
#        [297.29815974],
#        [297.64423229],
#        [297.95368018],
#        [298.23788022],
#        [298.50988624],
#        [298.80718986],
#        [299.09999534],
#        [299.43736296],
#        [299.81659242],
#        [300.25362263],
#        [300.77780165]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
# todo 
# add save charts 
# add save forecast.csv
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
